# %%
import numpy as np
import random
import scipy
import pickle
import os
import matplotlib.pyplot as plt
from sklearn import manifold, datasets, decomposition, ensemble, random_projection
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

if os.path.isfile('mnist_X.pickle') and os.path.isfile('mnist_Y.pickle'):
    mnist_X = pickle.load(open('mnist_X.pickle', 'rb'))
    mnist_Y = pickle.load(open('mnist_Y.pickle', 'rb'))
    mnist_X_mini = pickle.load(open('mnist_X_mini.pickle', 'rb'))
    mnist_Y_mini = pickle.load(open('mnist_Y_mini.pickle', 'rb'))
    mnist_X_middle = pickle.load(open('mnist_X_middle.pickle', 'rb'))
    mnist_Y_middle = pickle.load(open('mnist_Y_middle.pickle', 'rb'))
    mnist_X_tsne = pickle.load(open('mnist_X_tsne.pickle', 'rb'))
else:
    mnist = input_data.read_data_sets("../MNIST_data/", reshape=True)
    # notice that here we don't shuffle the data so the samples with same label are together
    sample_per_label = 1000
    random.seed(291)
    index_sampling = []
    for target_label in range(10):
        target_label_position = np.where(mnist.train.labels==target_label)[0]
        target_label_sampling = random.sample(list(target_label_position), sample_per_label)
        index_sampling.extend(target_label_sampling)
    mnist_X = mnist.train.images[index_sampling,:]
    mnist_Y = mnist.train.labels[index_sampling]
    mnist_X_middle = mnist_X[range(0,10000,2)]
    mnist_Y_middle = mnist_Y[range(0,10000,2)]
    mnist_X_mini = mnist_X[range(0,10000,10)]
    mnist_Y_mini = mnist_Y[range(0,10000,10)]
    
if os.path.isfile('mnist_Dist.pickle'):
    mnist_Dist = pickle.load(open('mnist_Dist.pickle', 'rb'))
    mnist_Dist_middle = pickle.load(open('mnist_Dist_middle.pickle', 'rb'))
    mnist_Dist_mini = pickle.load(open('mnist_Dist_mini.pickle', 'rb'))
else:
    mnist_Dist = scipy.spatial.distance.cdist(mnist_X,mnist_X)
    mnist_Dist_middle = scipy.spatial.distance.cdist(mnist_X_middle,mnist_X_middle)
    mnist_Dist_mini = scipy.spatial.distance.cdist(mnist_X_mini,mnist_X_mini)
# Out:
# /home/qiaojun/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
N = 10000

D = tf.placeholder(tf.float32,[N,N])
D_vec = tf.reshape(D,[-1,1])

x = tf.Variable(tf.truncated_normal([N, 2],mean=0.0,stddev=0.1), dtype = tf.float32)
xsq = tf.reduce_sum(x*x, 1)
xsq_vec = tf.reshape(xsq,[-1,1])
dsq = xsq_vec - 2*tf.matmul(x,tf.transpose(x)) + tf.transpose(xsq_vec)
# dsq = xsq_vec + tf.transpose(xsq_vec) - 2*tf.matmul(x,tf.transpose(x))
d_vec = tf.sqrt(tf.maximum(dsq,1e-20))
dsq_min = tf.reduce_min(dsq)
dsq_max = tf.reduce_max(dsq)
d_vec = tf.reshape(d_vec,[-1,1])

model_loss = tf.reduce_sum(tf.square(D_vec-d_vec))/2
avg_dist = model_loss/(N*(N-1)/2)

train = tf.train.GradientDescentOptimizer(1e-5).minimize(model_loss)
# train = tf.train.AdamOptimizer(1e-3).minimize(model_loss)

# %%
N = 10000

#sess = tf.Session()
#sess.run(tf.global_variables_initializer())

iter_times = 1000
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    x_init,d_init,model_loss_init = sess.run([x,d_vec,model_loss],{D: mnist_Dist[:N,:N]})
    
    for iters in range(iter_times):
        sess.run(train, {D: mnist_Dist[:N,:N]})
        loss,dist = sess.run([model_loss,avg_dist],{D: mnist_Dist[:N,:N]})
        d_min,d_max = sess.run([dsq_min,dsq_max],{D: mnist_Dist[:N,:N]})
        if iters%10 == 0:
            print('iter: ', iters, ' loss: ', loss, " distance: ", dist)
            print('min: ',d_min,' max: ',d_max)
        
    x_final = sess.run(x,{D: mnist_Dist[:N,:N]})
# Out:
# iter:  0  loss:  3650208000.0  distance:  73.01146
# min:  -9.536743e-07  max:  23.935783
# iter:  10  loss:  942887400.0  distance:  18.859634
# min:  -1.5258789e-05  max:  486.66486
# iter:  20  loss:  878702100.0  distance:  17.5758
# min:  -3.0517578e-05  max:  577.6332
# iter:  30  loss:  860318660.0  distance:  17.208094
# min:  -3.0517578e-05  max:  587.6737
# iter:  40  loss:  849959800.0  distance:  17.000896
# min:  -3.0517578e-05  max:  588.3788
# iter:  50  loss:  843644000.0  distance:  16.874567
# min:  -3.0517578e-05  max:  588.18665
# iter:  60  loss:  839524400.0  distance:  16.792168
# min:  -3.0517578e-05  max:  587.9955
# iter:  70  loss:  836766500.0  distance:  16.737003
# min:  -3.0517578e-05  max:  587.8588
# iter:  80  loss:  834890400.0  distance:  16.699476
# min:  -3.0517578e-05  max:  587.75494
# iter:  90  loss:  833586560.0  distance:  16.673399
# min:  -3.0517578e-05  max:  587.66785
# iter:  100  loss:  832661760.0  distance:  16.654902
# min:  -3.0517578e-05  max:  587.5882
# iter:  110  loss:  831991230.0  distance:  16.641489
# min:  -3.0517578e-05  max:  587.51025
# iter:  120  loss:  831491300.0  distance:  16.631489
# min:  -3.0517578e-05  max:  587.4298
# iter:  130  loss:  831107840.0  distance:  16.62382
# min:  -3.0517578e-05  max:  587.3449
# iter:  140  loss:  830803000.0  distance:  16.617722
# min:  -3.0517578e-05  max:  587.2542
# iter:  150  loss:  830550340.0  distance:  16.612667
# min:  -3.0517578e-05  max:  587.1568
# iter:  160  loss:  830329900.0  distance:  16.60826
# min:  -3.0517578e-05  max:  587.052
# iter:  170  loss:  830128000.0  distance:  16.60422
# min:  -3.0517578e-05  max:  586.9388
# iter:  180  loss:  829935550.0  distance:  16.60037
# min:  -3.0517578e-05  max:  586.8161
# iter:  190  loss:  829745000.0  distance:  16.59656
# min:  -1.5258789e-05  max:  586.6826
# iter:  200  loss:  829550660.0  distance:  16.592672
# min:  -1.5258789e-05  max:  586.53687
# iter:  210  loss:  829347800.0  distance:  16.588614
# min:  -3.0517578e-05  max:  586.3777
# iter:  220  loss:  829132540.0  distance:  16.584309
# min:  -3.0517578e-05  max:  586.2035
# iter:  230  loss:  828901250.0  distance:  16.579683
# iter:  850  loss:  759980400.0  distance:  15.201128
# min:  -3.0517578e-05  max:  577.8123
# iter:  860  loss:  758687700.0  distance:  15.175271
# min:  -3.0517578e-05  max:  576.9811
# iter:  870  loss:  757421300.0  distance:  15.149941
# min:  -3.0517578e-05  max:  575.75867
# iter:  880  loss:  756180740.0  distance:  15.125127
# min:  -3.0517578e-05  max:  574.14886
# iter:  890  loss:  754965900.0  distance:  15.100828
# min:  -3.0517578e-05  max:  572.15717
# iter:  900  loss:  753776300.0  distance:  15.077034
# min:  -3.0517578e-05  max:  569.78577
# iter:  910  loss:  752610100.0  distance:  15.053707
# min:  -3.0517578e-05  max:  567.04114
# iter:  920  loss:  751466400.0  distance:  15.03083
# min:  -3.0517578e-05  max:  563.93475
# iter:  930  loss:  750342800.0  distance:  15.008356
# min:  -3.0517578e-05  max:  560.4788
# iter:  940  loss:  749237700.0  distance:  14.986253
# min:  -1.5258789e-05  max:  556.6841
# iter:  950  loss:  748152640.0  distance:  14.964549
# min:  -3.0517578e-05  max:  552.5604
# iter:  960  loss:  747088400.0  distance:  14.943262
# min:  -1.5258789e-05  max:  554.2217
# iter:  970  loss:  746044200.0  distance:  14.922377
# min:  -1.5258789e-05  max:  555.0206
# iter:  980  loss:  745021600.0  distance:  14.901921
# min:  -3.0517578e-05  max:  554.7628
# iter:  990  loss:  744019260.0  distance:  14.881873
# min:  -3.0517578e-05  max:  553.44824

# %%
x_init
# Out:
# array([[ 0.06441443, -0.07531521],
#        [ 0.01506112,  0.06399938],
#        [-0.03029063,  0.122145  ],
#        ...,
#        [-0.09918334, -0.02763354],
#        [-0.07811039,  0.16697553],
#        [-0.06221091,  0.00628622]], dtype=float32)

# %%
x_final
# Out:
# array([[ 6.9011483 , -8.154414  ],
#        [ 1.7845674 ,  5.7130003 ],
#        [-2.7148871 ,  8.928509  ],
#        ...,
#        [-2.3081021 , -0.841923  ],
#        [-2.7854218 ,  5.4045076 ],
#        [-4.2156777 ,  0.05611131]], dtype=float32)

# %%
np.max(np.abs(x_init))
# Out:
# 0.19997577

# %%
def plot_embedding_2d(X, Y, title=None):

    # x_min, x_max = np.min(X,axis=0), np.max(X,axis=0)
    # X = (X - x_min) / (x_max - x_min)
    
    color_space = ['k','grey','r','y','g','c','b','m','orange','navy']
    
    fig = plt.figure(figsize=[15,15])
    ax = fig.add_subplot(1, 1, 1)
    
    for i in range(X.shape[0]):
        ax.text(X[i, 0], X[i, 1],str(Y[i]),
                 color=color_space[Y[i]],
                 fontdict={'weight': 'bold', 'size': 9})
    if title is not None:
        plt.title(title)
    
    x_range = np.max(np.abs(X))
    plt.xlim((-x_range, x_range))
    plt.ylim((-x_range, x_range))
    plt.savefig(title+".png")

# %%
mnist_Y_middle.shape
# Out:
# (5000,)

# %%
plot_embedding_2d(x_init, mnist_Y, 'initial')

# %%
plot_embedding_2d(x_final, mnist_Y, 'final')
